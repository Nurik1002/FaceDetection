# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.yaml")  # build a new model from scratch
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients

# %%
model.train(data="./data.yaml", epochs=100)
# Out:
# Ultralytics YOLOv8.0.114  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# yolo\engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=./data.yaml, epochs=100, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train11
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3011043 parameters, 3011027 gradients
#
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https:\github.com\ultralytics\assets\releases\download\v0.0.0\yolov8n.pt to yolov8n.pt...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.23M/6.23M [00:02<00:00, 2.97MB/s]
# AMP: checks passed
# train: Scanning C:\Users\Windows 10\Documents\nurgeldi\FaceDetection\Data\train\labels... 3672 images, 684 backgrounds,
# train: New cache created: C:\Users\Windows 10\Documents\nurgeldi\FaceDetection\Data\train\labels.cache
# val: Scanning C:\Users\Windows 10\Documents\nurgeldi\FaceDetection\Data\val\labels... 145 images, 26 backgrounds, 0 cor
# val: New cache created: C:\Users\Windows 10\Documents\nurgeldi\FaceDetection\Data\val\labels.cache
# Plotting labels to runs\detect\train11\labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train11
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.48G      3.236      3.799      3.728         13        640: 100%|██████████| 230/230 [00:22<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238     0.0995      0.134     0.0534     0.0158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.47G      2.522      2.941      2.797         16        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.229      0.164      0.102     0.0344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.57G      2.251      2.485      2.505          8        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.408      0.487      0.415      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.58G      2.091      2.226      2.348         20        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.568      0.548      0.536      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.48G       1.97      1.984      2.227         16        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.742      0.613      0.692      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.41G      1.867      1.891      2.119         21        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.726        0.6      0.703      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.71G      1.836      1.783      2.078         26        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.682      0.655      0.734      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.83G      1.767       1.69      2.014          8        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.826      0.739      0.803      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.63G      1.721      1.614      1.968         11        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.776      0.739      0.797      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.43G      1.684      1.547      1.942         17        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.822      0.739      0.825      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.41G      1.678      1.523      1.907         11        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.814      0.735      0.819      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.41G      1.632      1.486      1.884         16        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238       0.79      0.744      0.826      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.43G      1.628      1.439      1.876         12        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.816      0.752      0.846      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100       2.6G      1.616      1.412      1.851         34        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.845      0.798      0.867      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.48G      1.568      1.367      1.818         25        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.856      0.776      0.864      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100       2.8G      1.561      1.349      1.807         30        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238       0.86      0.727      0.853      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.49G      1.547      1.323      1.792         36        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.826      0.799      0.874      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.57G      1.529      1.287      1.771         34        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.812      0.794      0.877      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.59G      1.509      1.287      1.764         16        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.886      0.754      0.878      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.45G      1.502      1.246      1.738         26        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.898      0.815      0.917       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100       2.7G      1.484      1.239      1.727         23        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238       0.89      0.782      0.888      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.66G      1.458      1.195        1.7         27        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.901      0.794      0.904      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.41G      1.462      1.178      1.698         29        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.841      0.794      0.881      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.58G      1.437      1.165      1.677         15        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.874      0.818      0.888      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.66G      1.421      1.151      1.669         23        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.865      0.828      0.896      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.75G      1.427      1.136      1.662         37        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.827      0.828      0.885      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.62G      1.415      1.113      1.668         35        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.876      0.803        0.9      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100       2.5G      1.393      1.099      1.644         16        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.896      0.803      0.883      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.44G      1.385      1.101      1.635         32        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.849      0.824      0.899      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.49G      1.373      1.068      1.623         24        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.872      0.828      0.895       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.83G      1.374       1.06      1.614         26        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.879      0.854      0.912      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.64G      1.366      1.051      1.611         15        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.878      0.861       0.92      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.58G       1.32      1.007       1.58         13        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.886      0.819      0.908      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.46G      1.338      1.028      1.596         19        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.904      0.853      0.926      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.78G      1.335      1.031      1.576         19        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.898      0.848      0.929       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.47G      1.315      1.001      1.574         74        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.887      0.861      0.928      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100       2.6G      1.314     0.9958      1.576         18        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0
0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.41G      0.995     0.6533      1.294         24        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.955      0.861      0.945      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.46G     0.9956     0.6462      1.294         17        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.941       0.87      0.933      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.63G     0.9879      0.636      1.298         11        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.935      0.847      0.923      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.46G     0.9685     0.6328      1.279         22        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238       0.94       0.86      0.931      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.67G     0.9929     0.6421       1.29         33        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.932      0.867      0.927      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.49G     0.9892     0.6377      1.291         21        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.939      0.874      0.943      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100       2.8G      0.959     0.6195      1.272         34        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.966      0.836      0.929      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.62G     0.9666     0.6237      1.275         21        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.951      0.866      0.938      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100       2.5G     0.9809     0.6363       1.28         15        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.968      0.849      0.937      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.42G     0.9567     0.6217      1.268         14        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<0
#                    all        145        238      0.916      0.872      0.929      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.47G     0.9618     0.6208      1.275         25        640: 100%|██████████| 230/230 [00:19<00:00, 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        145        238      0.929      0.874      0.936       0.62
#
# 100 epochs completed in 0.572 hours.
# Optimizer stripped from runs\detect\train11\weights\last.pt, 6.2MB
# Optimizer stripped from runs\detect\train11\weights\best.pt, 6.2MB
#
# Validating runs\detect\train11\weights\best.pt...
# Ultralytics YOLOv8.0.114  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        145        238      0.897      0.881       0.93      0.631
# Speed: 0.9ms preprocess, 2.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\train11

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.114  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning C:\Users\Windows 10\Documents\nurgeldi\FaceDetection\Data\val\labels.cache... 145 images, 26 backgrounds,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:01
#                    all        145        238      0.883      0.891      0.932      0.632
# Speed: 0.9ms preprocess, 3.4ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs\detect\val
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.yolo.utils.metrics.Metric object
# confusion_matrix: <ultralytics.yolo.utils.metrics.ConfusionMatrix object at 0x000001E68C3ABAC0>
# fitness: 0.6616271092971135
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.63154])
# names: {0: 'Face'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.8826384708678775, 'metrics/recall(B)': 0.8907563025210085, 'metrics/mAP50(B)': 0.9323925424477538, 'metrics/mAP50-95(B)': 0.6315420611692646, 'fitness': 0.6616271092971135}
# save_dir: WindowsPath('runs/detect/val')
# speed: {'preprocess': 0.9390830993652344, 'inference': 3.399478978124158, 'loss': 0.0, 'postprocess': 2.2296806861614358}

# %%
import torch

# %%
torch.save(model, './yolov8_model.model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 torch.save(model, './yolov8_model.model')
#
# File ~\Documents\nurgeldi\fd_env\lib\site-packages\torch\serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439 if _use_new_zipfile_serialization:
#     440     with _open_zipfile_writer(f) as opened_zipfile:
# --> 441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#     443 else:
#
# File ~\Documents\nurgeldi\fd_env\lib\site-packages\torch\serialization.py:653, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     651 pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     652 pickler.persistent_id = persistent_id
# --> 653 pickler.dump(obj)
#     654 data_value = data_buf.getvalue()
#     655 zip_file.write_record('data.pkl', data_value, len(data_value))
#
# TypeError: cannot pickle 'torch._C.Generator' object

# %%
torch.__version__
# Out:
# '2.0.1+cu117'

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
import cv2 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
img = cv2.imread('./test5.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# %matplotlib inline
res = model(img)
res_plotted = res[0].plot()
plt.imshow(res_plotted)
# Out:
# 0: 640x640 19 Faces, 21.6ms
# Speed: 4.3ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
model2 = YOLO('yolov8n.pt')

# %%
img = mpimg.imread('test1.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
# %matplotlib inline
res = model(img)
res_plotted = res[0].plot()
plt.imshow(res_plotted)
# Out:
# 0: 448x640 1 Face, 5.2ms
# Speed: 3.1ms preprocess, 5.2ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
